# %%
import pandas as pd

# %%
df = pd.read_csv('../../outputs/results.csv')

# %%
df = df[df["data_path"] == "../../data/processed/lux_test_history.json"]
# Out:
#                                 model_name  \
# 0        Llama-3.1-8B-Instruct-lux-history
# 4                     Qwen3-8B-lux-history
# 6                    Llama-3.1-8B-Instruct
# 17                                Qwen3-8B
# 21              Ministral-8B-Instruct-2410
# 22  Ministral-8B-Instruct-2410-lux-history
#
#                                      data_path      bleu  bleu_precision_1  \
# 0   ../../data/processed/lux_test_history.json  0.008625          0.148808
# 4   ../../data/processed/lux_test_history.json  0.009813          0.155568
# 6   ../../data/processed/lux_test_history.json  0.008081          0.157121
# 17  ../../data/processed/lux_test_history.json  0.004707          0.157395
# 21  ../../data/processed/lux_test_history.json  0.005964          0.164916
# 22  ../../data/processed/lux_test_history.json  0.009949          0.153254
#
#     bleu_precision_2  bleu_precision_3  bleu_precision_4  brevity_penalty  \
# ...

# %%
df.to_csv('../../outputs/wassa2026_results.csv', index=False)
